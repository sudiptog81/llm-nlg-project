# %%
MODEL_NAME = "llama2-7b"
DATASET_PATH = f"drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/{MODEL_NAME}/processed"
TOPICS = [
  "Indian climate",
  "Indian defense",
  "Indian economy",
  "Indian infrastructure",
]

# %%
import pandas as pd

# %%
for topic in TOPICS:
  df = pd.read_csv(f'{DATASET_PATH}/../topics/{topic}/topics.csv')
  print(MODEL_NAME, topic, '=>', df.head(4)['Name'].tolist()[1:])
# Out:
# llama2-7b Indian climate => ['0_climate_indian_india_change', '1_summer_winter_temperature_season', '2_also_people_may_know']
# llama2-7b Indian defense => ['0_minister_defense_indian_china', '1_indian_defense_india_budget', '2_pakistan_kashmir_indian_minister']
# llama2-7b Indian economy => ['0_economy_indian_growth_india', '1_however_look_possible_think', '2_india_minister_delhi_new']
# llama2-7b Indian infrastructure => ['0_indian_infrastructure_india_sector', '1_solar_firm_indian_larsen', '2_however_mean_one_reactions']

# %%
MODEL_NAME = "gpt2-medium"
DATASET_PATH = f"drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/{MODEL_NAME}/processed"
TOPICS = [
  "Indian climate",
  "Indian defense",
  "Indian economy",
  "Indian infrastructure",
]

# %%
for topic in TOPICS:
  df = pd.read_csv(f'{DATASET_PATH}/../topics/{topic}/topics.csv')
  print(MODEL_NAME, topic, '=>', df.head(4)['Name'].tolist()[1:])
# Out:
# gpt2-medium Indian climate => ['0_climate_indian_change_ice', '1_thats_going_think_thing', '2_population_live_land_country']
# gpt2-medium Indian defense => ['0_minister_defense_indian_israel', '1_defense_indian_said_minister', '2_russian_ukraine_russia_shoigu']
# gpt2-medium Indian economy => ['0_indian_economy_india_indias', '1_china_chinese_chinas_growth', '2_think_need_make_true']
# gpt2-medium Indian infrastructure => ['0_infrastructure_indian_india_said', '1_project_economic_jobs_private', '2_going_problem_idea_dont']
