# %%
# %%capture
# %pip install bertopic

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from bertopic import BERTopic

# %%
topic_model = BERTopic.load("drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/models/falcon/pca-kmeans.model")

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                       Name  \
# 0      0    586           0_economy_economic_growth_impact
# 1      1    505         1_climate_change_variability_ocean
# 2      2    452        2_defence_military_security_defense
# 3      3    440  3_infrastructure_development_public_urban
#
#                                       Representation  \
# 0  [economy, economic, growth, impact, developmen...
# 1  [climate, change, variability, ocean, model, s...
# 2  [defence, military, security, defense, policy,...
# 3  [infrastructure, development, public, urban, p...
#
#                                              KeyBERT  \
# 0  [economy, economic, economics, gdp, reforms, i...
# 1  [climate, agriculture, monsoon, agricultural, ...
# 2  [defence, defense, military, procurement, army...
# 3  [infrastructure, economy, transportation, econ...
#
#                                                  MMR  \
# 0  [economy, economic, growth, impact, developmen...
# 1  [climate, change, variability, ocean, model, s...
# 2  [defence, military, security, defense, policy,...
# 3  [infrastructure, development, public, urban, p...
#
#                                  Representative_Docs
# 0  [essays money and finance the economy the fast...
# 1  [and agriculturean perspective abstract summar...
# 2  [review vol defence the military modernisation...
# 3  [urban multiplier study national infrastructur...

# %%
topic_model
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_auto_reduce_topics',
#  '_c_tf_idf',
#  '_cluster_embeddings',
#  '_combine_zeroshot_topics',
#  '_create_topic_vectors',
#  '_extract_embeddings',
#  '_extract_representative_docs',
#  '_extract_topics',
#  '_extract_words_per_topic',
#  '_get_param_names',
#  '_guided_topic_modeling',
#  '_images_to_text',
#  '_is_zeroshot',
#  '_map_predictions',
#  '_map_probabilities',
#  '_merged_topics',
#  '_outliers',
#  '_preprocess_text',
#  '_reduce_dimensionality',
#  '_reduce_to_n_topics',
#  '_reduce_topics',
#  '_save_representative_docs',
#  '_sort_mappings_by_frequency',
#  '_top_n_idx_sparse',
#  '_top_n_values_sparse',
#  '_update_topic_size',
#  '_zeroshot_topic_modeling',
#  'approximate_distribution',
#  'c_tf_idf_',
#  'calculate_probabilities',
#  'ctfidf_model',
#  'custom_labels_',
#  'embedding_model',
#  'find_topics',
#  'fit',
#  'fit_transform',
#  'generate_topic_labels',
#  'get_document_info',
#  'get_params',
#  'get_representative_docs',
#  'get_topic',
#  'get_topic_freq',
#  'get_topic_info',
#  'get_topic_tree',
#  'get_topics',
#  'hdbscan_model',
#  'hierarchical_topics',
#  'language',
#  'load',
#  'low_memory',
#  'merge_models',
#  'merge_topics',
#  'min_topic_size',
#  'n_gram_range',
#  'nr_topics',
#  'partial_fit',
#  'probabilities_',
#  'push_to_hf_hub',
#  'reduce_outliers',
#  'reduce_topics',
#  'representation_model',
#  'representative_docs_',
#  'representative_images_',
#  'save',
#  'seed_topic_list',
#  'set_topic_labels',
#  'top_n_words',
#  'topic_aspects_',
#  'topic_embeddings_',
#  'topic_labels_',
#  'topic_mapper_',
#  'topic_representations_',
#  'topic_sizes_',
#  'topics_',
#  'topics_over_time',
#  'topics_per_class',
#  'transform',
#  'umap_model',
#  'update_topics',
#  'vectorizer_model',
#  'verbose',
#  'visualize_approximate_distribution',
#  'visualize_barchart',
#  'visualize_distribution',
#  'visualize_documents',
#  'visualize_heatmap',
#  'visualize_hierarchical_documents',
#  'visualize_hierarchy',
#  'visualize_term_rank',
#  'visualize_topics',
#  'visualize_topics_over_time',
#  'visualize_topics_per_class',
#  'zeroshot_min_similarity',
#  'zeroshot_topic_list']

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="870a0e76-ac73-4bf3-b19f-1491072b10d2" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("870a0e76-ac73-4bf3-b19f-1491072b10d2")) {                    Plotly.newPlot(                        "870a0e76-ac73-4bf3-b19f-1491072b10d2",                        [{"customdata":[[0,"economy | economic | growth | impact | development",586],[1,"climate | change | variability | ocean | model",505],[2,"defence | military | security | defense | policy",452],[3,"infrastructure | development | public | urban | paper",440]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[586,505,452,440],"sizemode":"area","sizeref":0.36625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1.2753397226333618,0.7046278715133667,0.5116552710533142,1.7072347402572632],"xaxis":"x","y":[3.707984447479248,5.581964015960693,4.078731060028076,4.39371395111084],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"t ...
