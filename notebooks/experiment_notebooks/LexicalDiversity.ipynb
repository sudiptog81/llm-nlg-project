# %%
# %pip install lexical-diversity
# Out:
# Collecting lexical-diversity
#   Downloading lexical_diversity-0.1.1-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: lexical-diversity
# Successfully installed lexical-diversity-0.1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !python -m spacy download en_core_web_lg

# %%
import spacy
from lexical_diversity import lex_div as ld

nlp = spacy.load("en_core_web_lg")

def lemmatize(text):
  doc = nlp(text)
  lemmatized_text = [token.lemma_ for token in doc]
  return lemmatized_text

# %%
def get_diversity_stats(lemmatized_text):
  return dict({
    'simple_ttr': ld.ttr(lemmatized_text),
    'root_ttr': ld.root_ttr(lemmatized_text),
    'log_ttr': ld.log_ttr(lemmatized_text),
    'mass_ttr': ld.maas_ttr(lemmatized_text),
    'msttr': ld.msttr(lemmatized_text, window_length=25),
    'mattr': ld.mattr(lemmatized_text, window_length=25),
    'hdd': ld.hdd(lemmatized_text),
    'mtld': ld.mtld(lemmatized_text),
    'mtld_ma_wrap': ld.mtld_ma_wrap(lemmatized_text),
    'mtld_ma_bid': ld.mtld_ma_bid(lemmatized_text),
  })

# %% [markdown]
# ## Data - LLaMA-2 (SAME)

# %%
import re
import pandas as pd

dfs = []
TOPICS = ['Indian climate', 'Indian defense']
for topic in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-climate-defense/{topic}/data.csv')
  dfs.append(df)
TOPICS = ['Indian economy', 'Indian infrastructure']
for topic in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-economy-infra/{topic}/data.csv')
  dfs.append(df[:500])

TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure', 'Combined']

# %%
df_combined = pd.DataFrame()

for df in dfs:
  df_combined = df_combined.append(df, ignore_index=True)

dfs.append(df_combined)
df_combined
# Out:
# <ipython-input-19-1d8771281961>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_combined = df_combined.append(df, ignore_index=True)
#                      Prompt  \
# 0            Indian climate
# 1            Indian climate
# 2            Indian climate
# 3            Indian climate
# 4            Indian climate
# ...                     ...
# 1995  Indian infrastructure
# 1996  Indian infrastructure
# 1997  Indian infrastructure
# 1998  Indian infrastructure
# 1999  Indian infrastructure
#
#                                          Generated Text    i  MAX_LEN
# 0     Indian climate is a tropical one. It is hot an...    0      181
# 1     Indian climate is tropical in nature. Therefor...    1      189
# 2     Indian climate is divided into three main seas...    2      199
# 3     Indian climate change: Heatwaves, droughts, fl...    3      194
# 4     Indian climate is a combination of three seaso...    4      182
# ...                                                 ...  ...      ...
# 1995  Indian infrastructure sector has been growing ...  495      185
# 1996  Indian infrastructure sector is in the midst o...  496      184
# 1997  Indian infrastructure companies have been on a...  497      192
# 1998  Indian infrastructure sector to see 10% growth...  498      186
# 1999  Indian infrastructure sector is set to grow by...  499      180
#
# [2000 rows x 4 columns]

# %%
# !mkdir -p "drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/same/llama2"

# %%
for theme, df in zip(TOPICS, dfs):
  diversity_stats_df = df['Generated Text'].apply(lambda x: pd.Series(get_diversity_stats(lemmatize(x))))
  df = pd.concat([df, diversity_stats_df], axis=1)
  df.to_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/same/llama2/{theme}.csv', index=False)
  print('THEME:', theme)
  print(df.describe())
# Out:
# THEME: Indian climate
#                 i     MAX_LEN  simple_ttr    root_ttr     log_ttr    mass_ttr  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   249.500000  190.276000    0.559554    6.538296    0.881118    0.055696
# std    144.481833    6.185819    0.060061    0.716607    0.018553    0.008245
# min      0.000000  180.000000    0.404624    4.370957    0.822511    0.033601
# 25%    124.750000  185.000000    0.514883    6.114954    0.868492    0.050097
# 50%    249.500000  191.000000    0.556213    6.624830    0.881040    0.055011
# 75%    374.250000  196.000000    0.592416    7.065598    0.892934    0.060798
# max    499.000000  200.000000    0.795455    8.353351    0.939527    0.084086
#
#             msttr       mattr         hdd        mtld  mtld_ma_wrap  \
# count  500.000000  500.000000  500.000000  500.000000    500.000000
# mean     0.832140    0.832076    0.751589   49.155613     48.978330
# std      0.041691    0.039575    0.038119   13.626896     13.528549
# min      0.712000    0.702056    0.620520   25.838174     23.305344
# 25%      0.806667    0.805829    0.726398   39.619968     39.829856
# 50%      0.833333    0.831205    0.751411   46.814188     46.286387
# 75%      0.860000    0.859051    0.779323   54.966782     56.161485
# max      0.946667    0.937857    0.859966  130.000000    117.100000
#
#        mtld_ma_bid
# count   500.000000
# mean     44.926328
# std      14.521284
# min       0.000000
# 25%      36.103165
# 50%      42.519547
# 75%      52.183096
# max     112.036325
# THEME: Indian defense
#                 i     MAX_LEN  simple_ttr    root_ttr     log_ttr    mass_ttr  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   249.500000  189.452000    0.636783    6.800674    0.904111    0.046392
# std    144.481833    6.008319    0.077217    0.722009    0.021395    0.009136
# min      0.000000  180.000000    0.444444    2.773501    0.840606    0.019396
# 25%    124.750000  184.000000    0.584700    6.305288    0.889870    0.040313
# 50%    249.500000  189.000000    0.633461    6.802193    0.903680    0.046086
# 75%    374.250000  195.000000    0.685317    7.307966    0.918751    0.052251
# max    499.000000  200.000000    0.886364    8.421519    0.968123    0.091825
#
#             msttr       mattr         hdd        mtld  mtld_ma_wrap  \
# count  500.000000  500.000000  500.000000  500.000000    500.000000
# mean     0.883602    0.881899    0.798909   70.202863     68.688557
# std      0.035368    0.032018    0.061666   18.454829     16.319025
# min      0.769231    0.768058    0.000000   14.386667     13.076923
# 25%      0.866000    0.862854    0.777578   57.406497     57.853909
# 50%      0.886667    0.883112    0.802572   68.136700     66.781279
# 75%      0.904000    0.902395    0.827329   79.653989     78.159510
# max      1.000000    0.976000    0.909263  148.120000    125.035461
#
#        mtld_ma_bid
# count   500.000000
# mean     53.336758
# std      24.431620
# min       0.000000
# 25%      44.960951
# 50%      56.018350
# 50%     249.500000   190.000000     0.594937     6.861745     0.894463
# 75%     374.250000   195.000000     0.641412     7.250616     0.907346
# max     499.000000   200.000000     0.906250     8.768776     0.971596
#
#           mass_ttr        msttr        mattr          hdd         mtld  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.049882     0.864871     0.865234     0.781427    61.857932
# std       0.008698     0.041447     0.039050     0.052405    17.547062
# min       0.018871     0.712000     0.702056     0.000000    14.386667
# 25%       0.044333     0.840000     0.840918     0.757229    49.267619
# 50%       0.049565     0.866667     0.869955     0.786123    60.102021
# 75%       0.055391     0.893333     0.893576     0.809997    72.475162
# max       0.091825     1.000000     0.976000     0.909263   148.120000
#
#        mtld_ma_wrap  mtld_ma_bid
# count   2000.000000  2000.000000
# mean      61.285036    52.506696
# std       16.288147    20.083328
# min       13.076923     0.000000
# 25%       49.176732    41.996913
# 50%       60.441571    52.474394
# 75%       71.596082    64.502288
# max      130.000000   127.833333

# %%
TOPICS[-1:]
# Out:
# ['Combined']

# %%
for theme, df in zip(TOPICS[-1:], dfs[-1:]):
  diversity_stats_df = df['Generated Text'].apply(lambda x: pd.Series(get_diversity_stats(lemmatize(x))))
  df = pd.concat([df, diversity_stats_df], axis=1)
  df.to_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/same/llama2/{theme}.csv', index=False)
  print('THEME:', theme)
  print(df.describe())
# Out:
# THEME: Combined
#                  i      MAX_LEN   simple_ttr     root_ttr      log_ttr  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    249.500000   189.817000     0.602097     6.788698     0.894641
# std     144.373376     6.103781     0.071512     0.674939     0.020585
# min       0.000000   180.000000     0.404624     2.773501     0.822511
# 25%     124.750000   184.000000     0.553333     6.386232     0.880959
# 50%     249.500000   190.000000     0.594937     6.861745     0.894463
# 75%     374.250000   195.000000     0.641412     7.250616     0.907346
# max     499.000000   200.000000     0.906250     8.768776     0.971596
#
#           mass_ttr        msttr        mattr          hdd         mtld  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.049882     0.864871     0.865234     0.781427    61.857932
# std       0.008698     0.041447     0.039050     0.052405    17.547062
# min       0.018871     0.712000     0.702056     0.000000    14.386667
# 25%       0.044333     0.840000     0.840918     0.757229    49.267619
# 50%       0.049565     0.866667     0.869955     0.786123    60.102021
# 75%       0.055391     0.893333     0.893576     0.809997    72.475162
# max       0.091825     1.000000     0.976000     0.909263   148.120000
#
#        mtld_ma_wrap  mtld_ma_bid
# count   2000.000000  2000.000000
# mean      61.285036    52.506696
# std       16.288147    20.083328
# min       13.076923     0.000000
# 25%       49.176732    41.996913
# 50%       60.441571    52.474394
# 75%       71.596082    64.502288
# max      130.000000   127.833333

# %% [markdown]
# ## Data - LLaMA-2 (DIFFERENT)

# %%
import re
import pandas as pd

dfs = []
TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure']
for topic in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-google-scholar/{topic}/data.csv')
  dfs.append(df)

TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure', 'Combined']

# %%
df_combined = pd.DataFrame()

for df in dfs:
  df_combined = df_combined.append(df, ignore_index=True)

dfs.append(df_combined)
df_combined
# Out:
# <ipython-input-25-1d8771281961>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_combined = df_combined.append(df, ignore_index=True)
#                    Category  \
# 0            Indian climate
# 1            Indian climate
# 2            Indian climate
# 3            Indian climate
# 4            Indian climate
# ...                     ...
# 1978  Indian infrastructure
# 1979  Indian infrastructure
# 1980  Indian infrastructure
# 1981  Indian infrastructure
# 1982  Indian infrastructure
#
#                                                  Prompt  \
# 0     Impact of climate change on Indian agriculture...
# 1     The predictive state: science, territory and t...
# 2     Water resources and climate change: An Indian ...
# 3     Fractal dimensional analysis of Indian climati...
# 4     Temperature and rainfall extremes change under...
# ...                                                 ...
# 1978  What Causes Agglomeration—Policy or Infrastruc...
# 1979     The Scenario of FDI in Infrastructure of India
# 1980  The Impact Of Gaja Cyclone On Paddy And Rural ...
# 1981  South-South investment in infrastructure: the ...
# 1982  Critical Assessment of Infrastructure Investme...
#
#                                          Generated Text    i  MAX_LEN
# 0     Impact of climate change on Indian agriculture...    0      182
# 1     The predictive state: science, territory and t...    1      193
# 2     Water resources and climate change: An Indian ...    2      190
# 3     Fractal dimensional analysis of Indian climati...    3      184
# 4     Temperature and rainfall extremes change under...    4      180
# ...                                                 ...  ...      ...
# 1978  What Causes Agglomeration—Policy or Infrastruc...  496      182
# 1979  The Scenario of FDI in Infrastructure of India...  497      187
# 1980  The Impact Of Gaja Cyclone On Paddy And Rural ...  498      194
# 1981  South-South investment in infrastructure: the ...  499      194
# 1982  Critical Assessment of Infrastructure Investme...  500      193
#
# [1983 rows x 5 columns]

# %%
# !mkdir -p "drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/llama2"

# %%
for theme, df in zip(TOPICS, dfs):
  diversity_stats_df = df['Generated Text'].apply(lambda x: pd.Series(get_diversity_stats(lemmatize(x))))
  df = pd.concat([df, diversity_stats_df], axis=1)
  df.to_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/llama2/{theme}.csv', index=False)
  print('THEME:', theme)
  print(df.describe())
# Out:
# THEME: Indian climate
#                 i     MAX_LEN  simple_ttr    root_ttr     log_ttr    mass_ttr  \
# count  501.000000  501.000000  501.000000  501.000000  501.000000  501.000000
# mean   250.000000  190.281437    0.590563    7.007476    0.892987    0.049728
# std    144.770508    5.973494    0.062027    0.683749    0.017741    0.007608
# min      0.000000  180.000000    0.452514    3.400000    0.844503    0.009703
# 25%    125.000000  185.000000    0.548913    6.712196    0.880801    0.044747
# 50%    250.000000  190.000000    0.582734    7.062970    0.891774    0.049991
# 75%    375.000000  196.000000    0.623762    7.428703    0.903803    0.054561
# max    500.000000  200.000000    0.958333    8.433803    0.986608    0.085707
# %%
dfs[-1]
# Out:
#                    Category  \
# 0            Indian climate
# 1            Indian climate
# 2            Indian climate
# 3            Indian climate
# 4            Indian climate
# ...                     ...
# 1978  Indian infrastructure
# 1979  Indian infrastructure
# 1980  Indian infrastructure
# 1981  Indian infrastructure
# 1982  Indian infrastructure
#
#                                                  Prompt  \
# 0     Impact of climate change on Indian agriculture...
# 1     The predictive state: science, territory and t...
# 2     Water resources and climate change: An Indian ...
# 3     Fractal dimensional analysis of Indian climati...
# 4     Temperature and rainfall extremes change under...
# ...                                                 ...
# 1978  What Causes Agglomeration—Policy or Infrastruc...
# 1979     The Scenario of FDI in Infrastructure of India
# 1980  The Impact Of Gaja Cyclone On Paddy And Rural ...
# 1981  South-South investment in infrastructure: the ...
# 1982  Critical Assessment of Infrastructure Investme...
#
#                                          Generated Text    i  MAX_LEN
# 0     Impact of climate change on Indian agriculture...    0      182
# 1     The predictive state: science, territory and t...    1      193
# 2     Water resources and climate change: An Indian ...    2      190
# 3     Fractal dimensional analysis of Indian climati...    3      184
# 4     Temperature and rainfall extremes change under...    4      180
# ...                                                 ...  ...      ...
# 1978  What Causes Agglomeration—Policy or Infrastruc...  496      182
# 1979  The Scenario of FDI in Infrastructure of India...  497      187
# 1980  The Impact Of Gaja Cyclone On Paddy And Rural ...  498      194
# 1981  South-South investment in infrastructure: the ...  499      194
# 1982  Critical Assessment of Infrastructure Investme...  500      193
#
# [1983 rows x 5 columns]

# %%
# !mkdir -p "drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/llama2"

# %%
for theme, df in zip(TOPICS[-1:], dfs[-1:]):
  diversity_stats_df = df['Generated Text'].apply(lambda x: pd.Series(get_diversity_stats(lemmatize(x))))
  df = pd.concat([df, diversity_stats_df], axis=1)
  df.to_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/llama2/{theme}.csv', index=False)
  print('THEME:', theme)
  print(df.describe())
# Out:
# THEME: Combined
#                  i      MAX_LEN   simple_ttr     root_ttr      log_ttr  \
# count  1983.000000  1983.000000  1983.000000  1983.000000  1983.000000
# mean    247.458396   190.032779     0.582690     6.927642     0.890280
# std     143.288853     6.040933     0.064747     0.743945     0.018376
# min       0.000000   180.000000     0.417112     2.713602     0.832846
# 25%     123.500000   185.000000     0.541667     6.631391     0.878850
# 50%     247.000000   190.000000     0.576087     7.027819     0.890049
# 75%     371.000000   195.000000     0.614379     7.389618     0.901057
# max     500.000000   200.000000     0.958333     9.138115     0.986608
#
#           mass_ttr        msttr        mattr          hdd         mtld  \
# count  1983.000000  1983.000000  1983.000000  1983.000000  1983.000000
# mean      0.050994     0.853084     0.852426     0.762147    57.706087
# std       0.007984     0.039105     0.036247     0.110194    16.868804
# min       0.008241     0.520000     0.608696     0.000000    16.940000
# 25%       0.046155     0.833333     0.833475     0.756090    47.875148
# 50%       0.050879     0.856000     0.856563     0.777680    55.851155
# 75%       0.055379     0.880000     0.875939     0.798696    65.716318
# max       0.116270     0.960000     0.958333     0.957769   376.360000
#
#        mtld_ma_wrap  mtld_ma_bid
# count   1983.000000  1983.000000
# mean      57.352504    50.851037
# std       14.376302    15.817304
# min       13.000000     0.000000
# 25%       48.058811    42.668572
# 50%       56.144654    50.696364
# 75%       65.340536    58.873708
# max      126.000000   115.408470

# %% [markdown]
# ## Data - Falcon (SAME)

# %%
import re
import pandas as pd

dfs = []
TOPICS = ['Indian climate', 'Indian defence', 'Indian economy', 'Indian infrastructure']
for topic in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/falcon-7b-200-24012024-v3/{topic}/data.csv')
  dfs.append(df)

TOPICS = ['Indian climate', 'Indian defence', 'Indian economy', 'Indian infrastructure', 'Combined']

# %%
df_combined = pd.DataFrame()

for df in dfs:
  df_combined = df_combined.append(df, ignore_index=True)

dfs.append(df_combined)
df_combined
# Out:
# <ipython-input-33-1d8771281961>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_combined = df_combined.append(df, ignore_index=True)
#                    Category  \
# 0            Indian climate
# 1            Indian climate
# 2            Indian climate
# 3            Indian climate
# 4            Indian climate
# ...                     ...
# 1995  Indian infrastructure
# 1996  Indian infrastructure
# 1997  Indian infrastructure
# 1998  Indian infrastructure
# 1999  Indian infrastructure
#
#                                                  Prompt  Generated Text    i  \
# 0     Indian climate scientists have long complained...               0  189
# 1     Indian climate is characterized by great varia...               1  200
# 2     Indian climate is very hot, dry and humid. Peo...               2  186
# 3     Indian climate\nFrom Wikipedia, the free encyc...               3  193
# 4     Indian climate change adaptation strategy\nThe...               4  185
# ...                                                 ...             ...  ...
# 1995  Indian infrastructure company L&T is all set t...             495  186
# 1996  Indian infrastructure is facing an unprecedent...             496  200
# 1997  Indian infrastructure giant GVK Power and Infr...             497  190
# 1998  Indian infrastructure company GMR Group has be...             498  184
# 1999  Indian infrastructure is in poor shape, a fact...             499  181
#
#       MAX_LEN
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1995      NaN
# 1996      NaN
# 1997      NaN
# 1998      NaN
# 1999      NaN
#
# [2000 rows x 5 columns]

# %%
# !mkdir -p "drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/same/falcon"

# %%
for theme, df in zip(TOPICS, dfs):
  diversity_stats_df = df['Prompt'].apply(lambda x: pd.Series(get_diversity_stats(lemmatize(x))))
  df = pd.concat([df, diversity_stats_df], axis=1)
  df.to_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/same/falcon/{theme}.csv', index=False)
  print('THEME:', theme)
  print(df.describe())
# Out:
# THEME: Indian climate
#        Generated Text           i  MAX_LEN  simple_ttr    root_ttr  \
# count      500.000000  500.000000      0.0  500.000000  500.000000
# mean       249.500000  189.900000      NaN    0.594627    7.031603
# std        144.481833    6.059657      NaN    0.076591    0.879908
# min          0.000000  180.000000      NaN    0.429348    2.666667
# 25%        124.750000  184.000000      NaN    0.541496    6.599385
# 50%        249.500000  190.000000      NaN    0.584240    7.166477
# 75%        374.250000  195.000000      NaN    0.634316    7.613195
# 75%       0.913678     0.051435     0.905238     0.899712     0.824231
# max       1.000000     0.072040     1.000000     1.000000     0.927728
#
#               mtld  mtld_ma_wrap  mtld_ma_bid
# count  2000.000000   2000.000000  2000.000000
# mean     70.142261     68.352517    56.777488
# std      18.255835     17.115384    23.473964
# min       0.000000     10.000000     0.000000
# 25%      57.666649     56.664479    47.113802
# 50%      68.523910     67.767134    58.913761
# 75%      81.826961     79.074167    71.000000
# max     179.386667    140.973684   141.212500

# %% [markdown]
# ## Data - Falcon (DIFFERENT)

# %%
import re
import pandas as pd

dfs = []
TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure']
for topic in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/falcon-7b-200-google-scholar-17012024/{topic}/data.csv')
  dfs.append(df)

TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure', 'Combined']

# %%
df_combined = pd.DataFrame()

for df in dfs:
  df_combined = df_combined.append(df, ignore_index=True)

dfs.append(df_combined)
df_combined
# Out:
# <ipython-input-37-1d8771281961>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_combined = df_combined.append(df, ignore_index=True)
#                    Category  \
# 0            Indian climate
# 1            Indian climate
# 2            Indian climate
# 3            Indian climate
# 4            Indian climate
# ...                     ...
# 1978  Indian infrastructure
# 1979  Indian infrastructure
# 1980  Indian infrastructure
# 1981  Indian infrastructure
# 1982  Indian infrastructure
#
#                                                  Prompt  \
# 0     Impact of climate change on Indian agriculture...
# 1     The predictive state: science, territory and t...
# 2     Water resources and climate change: An Indian ...
# 3     Fractal dimensional analysis of Indian climati...
# 4     Temperature and rainfall extremes change under...
# ...                                                 ...
# 1978  What Causes AgglomerationPolicy or Infrastruct...
# 1979     The Scenario of FDI in Infrastructure of India
# 1980  The Impact Of Gaja Cyclone On Paddy And Rural ...
# 1981  South-South investment in infrastructure: the ...
# 1982  Critical Assessment of Infrastructure Investme...
#
#                                          Generated Text    i  MAX_LEN
# 0     Impact of climate change on Indian agriculture...    0      198
# 1     The predictive state: science, territory and t...    1      190
# 2     Water resources and climate change: An Indian ...    2      180
# 3     Fractal dimensional analysis of Indian climati...    3      198
# 4     Temperature and rainfall extremes change under...    4      189
# ...                                                 ...  ...      ...
# 1978  What Causes AgglomerationPolicy or Infrastruct...  496      183
# 1979  The Scenario of FDI in Infrastructure of India...  497      194
# 1980  The Impact Of Gaja Cyclone On Paddy And Rural ...  498      198
# 1981  South-South investment in infrastructure: the ...  499      192
# 1982  Critical Assessment of Infrastructure Investme...  500      183
#
# [1983 rows x 5 columns]

# %%
# !mkdir -p "drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/falcon"

# %%
for theme, df in zip(TOPICS, dfs):
  diversity_stats_df = df['Generated Text'].apply(lambda x: pd.Series(get_diversity_stats(lemmatize(x))))
  df = pd.concat([df, diversity_stats_df], axis=1)
  df.to_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/falcon/{theme}.csv', index=False)
# std       0.009668     0.043093     0.041904     0.181022    17.832487
# min       0.000000     0.440000     0.334026     0.000000     0.000000
# 25%       0.044159     0.840000     0.836638     0.763879    49.313137
# 50%       0.049019     0.860000     0.859883     0.787560    58.616279
# 75%       0.054016     0.880000     0.878540     0.806590    68.544726
# max       0.102869     1.000000     1.000000     0.900225   219.520000
#
#        mtld_ma_wrap  mtld_ma_bid
# count   1983.000000  1983.000000
# mean      58.290028    49.623662
# std       16.030934    20.180102
# min       10.000000     0.000000
# 25%       48.920436    41.532495
# 50%       58.232143    51.759611
# 75%       67.437410    60.900302
# max      156.113208   146.734472

# %% [markdown]
# ## Reporting

# %% [markdown]
# #### LLaMA-2 SAME

# %%
import pandas as pd

report_df = pd.DataFrame()
TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure', 'Combined']
for theme in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/same/llama2/{theme}.csv')
  report_df = report_df.append({
      'theme': theme,
      'MAX_LEN': df['MAX_LEN'].mean(),
      'simple_ttr': df['simple_ttr'].mean(),
      'root_ttr': df['root_ttr'].mean(),
      'log_ttr': df['log_ttr'].mean(),
      'maas_ttr': df['mass_ttr'].mean(),
      'msttr': df['msttr'].mean(),
      'mattr': df['mattr'].mean(),
      'hdd': df['hdd'].mean(),
      'mtld': df['mtld'].mean(),
      'mtld_ma_wrap': df['mtld_ma_wrap'].mean(),
      'mtld_ma_bid': df['mtld_ma_bid'].mean(),
  }, ignore_index=True)

report_df
# Out:
# <ipython-input-5-e97f1f84be4b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-5-e97f1f84be4b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-5-e97f1f84be4b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-5-e97f1f84be4b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-5-e97f1f84be4b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
#                    theme  MAX_LEN  simple_ttr  root_ttr   log_ttr  maas_ttr  \
# 0         Indian climate  190.276    0.559554  6.538296  0.881118  0.055696
# 1         Indian defense  189.452    0.636783  6.800674  0.904111  0.046392
# 2         Indian economy  189.674    0.599143  6.841200  0.894397  0.049711
# 3  Indian infrastructure  189.866    0.612910  6.974624  0.898939  0.047731
# 4               Combined  189.817    0.602097  6.788698  0.894641  0.049882
#
#       msttr     mattr       hdd       mtld  mtld_ma_wrap  mtld_ma_bid
# 0  0.832140  0.832076  0.751589  49.155613     48.978330    44.926328
# 1  0.883602  0.881899  0.798909  70.202863     68.688557    53.336758
# 2  0.869656  0.873268  0.786984  62.823810     62.592828    54.541403
# 3  0.874087  0.873692  0.788224  65.249444     64.880428    57.222297
# 4  0.864871  0.865234  0.781427  61.857932     61.285036    52.506696

# %% [markdown]
# #### FALCON SAME

# %%
report_df = pd.DataFrame()
TOPICS = ['Indian climate', 'Indian defence', 'Indian economy', 'Indian infrastructure', 'Combined']
for theme in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/same/falcon/{theme}.csv')
  report_df = report_df.append({
      'theme': theme,
      'MAX_LEN': df['i'].mean(),
      'simple_ttr': df['simple_ttr'].mean(),
      'root_ttr': df['root_ttr'].mean(),
      'log_ttr': df['log_ttr'].mean(),
      'maas_ttr': df['mass_ttr'].mean(),
      'msttr': df['msttr'].mean(),
      'mattr': df['mattr'].mean(),
      'hdd': df['hdd'].mean(),
      'mtld': df['mtld'].mean(),
      'mtld_ma_wrap': df['mtld_ma_wrap'].mean(),
      'mtld_ma_bid': df['mtld_ma_bid'].mean(),
  }, ignore_index=True)

report_df
# Out:
# <ipython-input-6-5cb12b236c00>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-6-5cb12b236c00>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-6-5cb12b236c00>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-6-5cb12b236c00>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-6-5cb12b236c00>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
#                    theme  MAX_LEN  simple_ttr  root_ttr   log_ttr  maas_ttr  \
# 0         Indian climate  189.900    0.594627  7.031603  0.894201  0.049173
# 1         Indian defence  190.252    0.638263  7.119058  0.906615  0.044221
# 2         Indian economy  190.182    0.611832  7.030286  0.899077  0.047207
# 3  Indian infrastructure  190.110    0.640589  7.166018  0.907461  0.043737
# 4               Combined  190.111    0.621328  7.086741  0.901839  0.046085
#
#       msttr     mattr       hdd       mtld  mtld_ma_wrap  mtld_ma_bid
# 0  0.862199  0.862297  0.770547  62.653386     61.972035    55.223165
# 1  0.890433  0.884411  0.796046  74.724666     72.325245    56.988385
# 2  0.879628  0.880359  0.778959  68.079342     66.663638    58.476953
# 3  0.890693  0.885652  0.801840  75.111651     72.449151    56.421450
# 4  0.880738  0.878180  0.786848  70.142261     68.352517    56.777488

# %% [markdown]
# #### LLaMA-2 DIFFERENT

# %%
report_df = pd.DataFrame()
TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure', 'Combined']
for theme in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/llama2/{theme}.csv')
  report_df = report_df.append({
      'theme': theme,
      'MAX_LEN': df['MAX_LEN'].mean(),
      'simple_ttr': df['simple_ttr'].mean(),
      'root_ttr': df['root_ttr'].mean(),
      'log_ttr': df['log_ttr'].mean(),
      'maas_ttr': df['mass_ttr'].mean(),
      'msttr': df['msttr'].mean(),
      'mattr': df['mattr'].mean(),
      'hdd': df['hdd'].mean(),
      'mtld': df['mtld'].mean(),
      'mtld_ma_wrap': df['mtld_ma_wrap'].mean(),
      'mtld_ma_bid': df['mtld_ma_bid'].mean(),
  }, ignore_index=True)

report_df
# Out:
# <ipython-input-7-a9a124ad84b5>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-7-a9a124ad84b5>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-7-a9a124ad84b5>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-7-a9a124ad84b5>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-7-a9a124ad84b5>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
#                    theme     MAX_LEN  simple_ttr  root_ttr   log_ttr  \
# 0         Indian climate  190.281437    0.590563  7.007476  0.892987
# 1         Indian defense  190.235529    0.590145  6.984259  0.892696
# 2         Indian economy  189.847917    0.565967  6.771099  0.884628
# 3  Indian infrastructure  189.758483    0.583385  6.941172  0.890574
# 4               Combined  190.032779    0.582690  6.927642  0.890280
#
#    maas_ttr     msttr     mattr       hdd       mtld  mtld_ma_wrap  \
# 0  0.049728  0.858986  0.855897  0.772965  60.408203     59.826780
# 1  0.049993  0.857717  0.857009  0.758233  59.251547     59.207386
# 2  0.053485  0.838526  0.841270  0.740491  52.530323     52.049035
# 3  0.050873  0.856497  0.855059  0.775992  58.417324     58.104515
# 4  0.050994  0.853084  0.852426  0.762147  57.706087     57.352504
#
#    mtld_ma_bid
# 0    53.006217
# 1    51.684288
# 2    46.557558
# 3    51.976117
# 4    50.851037

# %% [markdown]
# #### FALCON DIFFERENT

# %%
report_df = pd.DataFrame()
TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure', 'Combined']
for theme in TOPICS:
  df = pd.read_csv(f'drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/diversity/different/falcon/{theme}.csv')
  report_df = report_df.append({
      'theme': theme,
      'MAX_LEN': df['MAX_LEN'].mean(),
      'simple_ttr': df['simple_ttr'].mean(),
      'root_ttr': df['root_ttr'].mean(),
      'log_ttr': df['log_ttr'].mean(),
      'maas_ttr': df['mass_ttr'].mean(),
      'msttr': df['msttr'].mean(),
      'mattr': df['mattr'].mean(),
      'hdd': df['hdd'].mean(),
      'mtld': df['mtld'].mean(),
      'mtld_ma_wrap': df['mtld_ma_wrap'].mean(),
      'mtld_ma_bid': df['mtld_ma_bid'].mean(),
  }, ignore_index=True)

report_df
# Out:
# <ipython-input-8-37b68e7aa129>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-8-37b68e7aa129>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-8-37b68e7aa129>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-8-37b68e7aa129>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# <ipython-input-8-37b68e7aa129>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
#                    theme     MAX_LEN  simple_ttr  root_ttr   log_ttr  \
# 0         Indian climate  190.041916    0.595385  7.155216  0.895250
# 1         Indian defense  190.544910    0.611065  7.031694  0.898516
# 2         Indian economy  190.050000    0.604452  6.666449  0.894857
# 3  Indian infrastructure  189.626747    0.592762  6.966247  0.893476
# 4               Combined  190.066062    0.600879  6.957956  0.895532
#
#    maas_ttr     msttr     mattr       hdd       mtld  mtld_ma_wrap  \
# 0  0.048269  0.862673  0.858050  0.767063  62.611663     61.004190
# 1  0.047722  0.857300  0.855074  0.746862  62.045965     60.348726
# 2  0.049839  0.849814  0.850891  0.711976  54.782784     53.328238
# 3  0.049475  0.859429  0.858115  0.750161  59.396287     58.270978
# 4  0.048815  0.857383  0.855582  0.744355  59.761345     58.290028
#
#    mtld_ma_bid
# 0    53.257405
# 1    49.998728
# 2    44.716949
# 3    50.315895
# 4    49.623662
