# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
TOPICS = ['Indian climate', 'Indian defense', 'Indian economy', 'Indian infrastructure']

# %%
pd.read_csv('/content/drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-climate-defense/Indian climate/data.csv').describe()
# Out:
#                 i     MAX_LEN
# count  500.000000  500.000000
# mean   249.500000  190.276000
# std    144.481833    6.185819
# min      0.000000  180.000000
# 25%    124.750000  185.000000
# 50%    249.500000  191.000000
# 75%    374.250000  196.000000
# max    499.000000  200.000000

# %%
pd.read_csv('/content/drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-climate-defense/Indian defense/data.csv').describe()
# Out:
#                 i     MAX_LEN
# count  500.000000  500.000000
# mean   249.500000  189.452000
# std    144.481833    6.008319
# min      0.000000  180.000000
# 25%    124.750000  184.000000
# 50%    249.500000  189.000000
# 75%    374.250000  195.000000
# max    499.000000  200.000000

# %%
pd.read_csv('/content/drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-economy-infra/Indian economy/data.csv')[:500].describe()
# Out:
#                 i     MAX_LEN
# count  500.000000  500.000000
# mean   249.500000  189.674000
# std    144.481833    6.213609
# min      0.000000  180.000000
# 25%    124.750000  184.000000
# 50%    249.500000  189.000000
# 75%    374.250000  195.000000
# max    499.000000  200.000000

# %%
pd.read_csv('/content/drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-economy-infra/Indian infrastructure/data.csv')[:500].describe()
# Out:
#                 i     MAX_LEN
# count  500.000000  500.000000
# mean   249.500000  189.866000
# std    144.481833    5.992317
# min      0.000000  180.000000
# 25%    124.750000  185.000000
# 50%    249.500000  190.000000
# 75%    374.250000  195.000000
# max    499.000000  200.000000

# %%
for t in TOPICS:
  print(t)
  df=pd.read_csv(f'/content/drive/MyDrive/DUCSResearch/Bias in LLMs/colab_notebooks/bias_llm/data/llama2-7b-200-google-scholar/{t}/data.csv')
  print(df.describe())
# Out:
# Indian climate
#                 i     MAX_LEN
# count  501.000000  501.000000
# mean   250.000000  190.281437
# std    144.770508    5.973494
# min      0.000000  180.000000
# 25%    125.000000  185.000000
# 50%    250.000000  190.000000
# 75%    375.000000  196.000000
# max    500.000000  200.000000
# Indian defense
#                 i     MAX_LEN
# count  501.000000  501.000000
# mean   250.000000  190.235529
# std    144.770508    6.005032
# min      0.000000  180.000000
# 25%    125.000000  185.000000
# 50%    250.000000  190.000000
# 75%    375.000000  196.000000
# max    500.000000  200.000000
# Indian economy
#                 i     MAX_LEN
# count  480.000000  480.000000
# mean   239.500000  189.847917
# std    138.708327    5.984304
# min      0.000000  180.000000
# 25%    119.750000  185.000000
# 50%    239.500000  190.000000
# 75%    359.250000  195.000000
# max    479.000000  200.000000
# Indian infrastructure
#                 i     MAX_LEN
# ...
